# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
# %matplotlib inline

# %%
dataset=pd.read_csv('https://raw.githubusercontent.com/gagan3012/stock-analysis/master/Train.csv',index_col="Date",parse_dates=True)

# %%
dataset.head(
)
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2012-01-03 to 2016-12-30
# Data columns (total 5 columns):
# Open      1258 non-null float64
# High      1258 non-null float64
# Low       1258 non-null float64
# Close     1258 non-null object
# Volume    1258 non-null object
# dtypes: float64(3), object(2)
# memory usage: 59.0+ KB

# %%
dataset['Open'].plot(figsize=(16,6))

# %%
dataset["Close"]=dataset["Close"].str.replace(',','').astype(float)

# %%
dataset["Volume"]=dataset["Volume"].str.replace(',','').astype(float)

# %%
dataset.head()
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7380500.0
# 2012-01-04  331.27  333.87  329.08  666.45   5749400.0
# 2012-01-05  329.83  330.75  326.89  657.21   6590300.0
# 2012-01-06  328.34  328.77  323.68  648.24   5405900.0
# 2012-01-09  322.04  322.29  309.46  620.76  11688800.0

# %%
dataset.rolling(7).mean().head(10)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2012-01-03         NaN         NaN         NaN         NaN           NaN
# 2012-01-04         NaN         NaN         NaN         NaN           NaN
# 2012-01-05         NaN         NaN         NaN         NaN           NaN
# 2012-01-06         NaN         NaN         NaN         NaN           NaN
# 2012-01-09         NaN         NaN         NaN         NaN           NaN
# 2012-01-10         NaN         NaN         NaN         NaN           NaN
# 2012-01-11  323.002857  325.392857  318.682857  643.132857  7.208100e+06
# 2012-01-12  321.457143  322.882857  316.841429  638.037143  6.691514e+06
# 2012-01-13  318.698571  319.801429  314.025714  631.870000  6.531857e+06
# 2012-01-17  316.552857  317.524286  311.851429  627.534286  6.137929e+06

# %%
dataset['Open'].plot(figsize=(16,6))
dataset.rolling(window=30).mean()['Close'].plot()

# %%
dataset['Close: 30 Day Mean'] = dataset['Close'].rolling(window=30).mean()
dataset[['Close','Close: 30 Day Mean']].plot(figsize=(16,6))

# %%
dataset['Close'].expanding(min_periods=1).mean().plot(figsize=(16,6))

# %%
training_set=dataset['Open']
training_set=pd.DataFrame(training_set)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /home/nbuser/anaconda3_23/lib/python3.4/site-packages
# Requirement already satisfied: pyyaml in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras)
# Requirement already satisfied: scipy>=0.14 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras)
# Requirement already satisfied: six>=1.9.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras)
# Requirement already satisfied: h5py in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras)
# Requirement already satisfied: numpy>=1.9.1 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras)
# You are using pip version 19.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install np_utils
# Out:
# Requirement already satisfied: np_utils in /home/nbuser/anaconda3_23/lib/python3.4/site-packages
# Requirement already satisfied: future>=0.16 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from np_utils)
# Requirement already satisfied: numpy>=1.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from np_utils)
# You are using pip version 19.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
 # !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /home/nbuser/anaconda3_23/lib/python3.4/site-packages
# Requirement already satisfied: grpcio>=1.8.6 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: protobuf>=3.6.1 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: six>=1.10.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: termcolor>=1.1.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: wheel>=0.26 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: google-pasta>=0.1.6 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: gast>=0.2.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: astor>=0.6.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: wrapt>=1.11.1 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: absl-py>=0.7.0 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorflow)
# Collecting enum34>=1.0.4 (from grpcio>=1.8.6->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/df/6e/46a0304561a07bda942c4283b67228d5b87d1ebd1189c866ede4b4cd6a0a/enum34-1.1.9-py3-none-any.whl
# Collecting futures>=2.2.0 (from grpcio>=1.8.6->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/05/80/f41cca0ea1ff69bce7e7a7d76182b47bb4e1a494380a532af3e8ee70b9ec/futures-3.1.1-py3-none-any.whl
# Requirement already satisfied: h5py in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from keras-applications>=1.0.6->tensorflow)
# Requirement already satisfied: setuptools in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from protobuf>=3.6.1->tensorflow)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow)
# Requirement already satisfied: markdown>=2.6.8 in /home/nbuser/anaconda3_23/lib/python3.4/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow)
# Installing collected packages: enum34, futures
# Successfully installed enum34-1.1.9 futures-3.1.1
# You are using pip version 19.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
regressor = Sequential()

# %%
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# WARNING:tensorflow:From /home/nbuser/anaconda3_23/lib/python3.4/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 1198/1198 [==============================] - 8s 6ms/step - loss: 0.0621
# Epoch 2/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0060
# Epoch 3/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0053
# Epoch 4/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0050
# Epoch 5/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0050
# Epoch 6/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0052
# Epoch 7/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0049
# Epoch 8/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0043
# Epoch 9/100
# 1198/1198 [==============================] - 7s 5ms/step - loss: 0.0045
# Epoch 10/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0043
# Epoch 11/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0038
# Epoch 12/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0041
# Epoch 13/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0039
# Epoch 14/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0037
# Epoch 15/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0037
# Epoch 16/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0035
# Epoch 17/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0035
# Epoch 18/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0036
# Epoch 19/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0035
# Epoch 20/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0032A: 1s - loss
# Epoch 21/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0036
# Epoch 22/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0033
# Epoch 23/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0036
# Epoch 24/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0030
# Epoch 25/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0032
# Epoch 26/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0033
# Epoch 27/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0035
# Epoch 28/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0032
# Epoch 29/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0030
# Epoch 30/100
# 1198/1198 [==============================] - 7s 5ms/step - loss: 0.0033
# Epoch 31/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0034
# Epoch 32/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0030
# Epoch 33/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0027
# Epoch 34/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0028
# Epoch 35/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0028
# Epoch 36/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0030
# Epoch 37/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0027
# Epoch 38/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0029
# Epoch 39/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0032
# Epoch 40/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0027
# Epoch 41/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0029
# Epoch 42/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0027
# Epoch 43/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0026
# Epoch 44/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0026
# Epoch 45/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0025A: 1s - lo
# Epoch 46/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0026
# Epoch 47/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0025
# Epoch 48/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0024
# Epoch 49/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0025
# Epoch 50/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0026
# Epoch 51/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0026
# Epoch 52/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0022
# Epoch 53/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0024
# Epoch 54/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0025
# Epoch 55/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0028
# Epoch 56/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0024
# Epoch 57/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0022
# Epoch 58/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0023
# Epoch 59/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0023
# Epoch 60/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0020
# Epoch 61/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 62/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0023
# Epoch 63/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0021
# Epoch 64/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0020
# Epoch 65/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0021
# Epoch 66/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0020
# Epoch 67/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 68/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0020
# Epoch 69/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 70/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0020
# Epoch 71/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 72/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0020
# Epoch 73/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 74/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0018
# Epoch 75/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0020
# Epoch 76/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0017
# Epoch 77/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 78/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0018
# Epoch 79/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 80/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019
# Epoch 81/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0021
# Epoch 82/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0018A: 2
# Epoch 83/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0018
# Epoch 84/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0017
# Epoch 85/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0017
# Epoch 86/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0018
# Epoch 87/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0017
# Epoch 88/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0017
# Epoch 89/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0015
# Epoch 90/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0018
# Epoch 91/100
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0014A: 1s - loss
# Epoch 92/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0015
# Epoch 93/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0015
# Epoch 94/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0018
# Epoch 95/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0014
# Epoch 96/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0016
# Epoch 97/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0014
# Epoch 98/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0015
# Epoch 99/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0016A: 1s - l
# Epoch 100/100
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0013

# %%
dataset_test = pd.read_csv('https://raw.githubusercontent.com/gagan3012/stock-analysis/master/Test.csv',index_col="Date",parse_dates=True)

# %%
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_test.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2017-01-03  778.81  789.63  775.80  786.14  1,657,300
# 2017-01-04  788.36  791.34  783.16  786.90  1,073,000
# 2017-01-05  786.08  794.48  785.02  794.02  1,335,200
# 2017-01-06  795.26  807.90  792.20  806.15  1,640,200
# 2017-01-09  806.40  809.97  802.83  806.65  1,272,400

# %%
dataset_test["Volume"] = dataset_test["Volume"].str.replace(',', '').astype(float)

# %%
test_set=dataset_test['Open']
test_set=pd.DataFrame(test_set)

# %%
dataset_total = pd.concat((dataset['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price=pd.DataFrame(predicted_stock_price)
predicted_stock_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
# 0    20 non-null float32
# dtypes: float32(1)
# memory usage: 160.0 bytes

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
